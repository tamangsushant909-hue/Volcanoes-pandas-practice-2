# %%
import pandas as pd

# DIRECT LINK to the Volcanic Eruption dataset — NO file needed!
url = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/eruptions.csv'
volcanoes = pd.read_csv(url)

# Test it works — shows first 5 rows
volcanoes.head()
# Out:
#    volcano_number            volcano_name  eruption_number  \
# 0          266030                 Soputan            22354
# 1          343100              San Miguel            22355
# 2          233020  Fournaise, Piton de la            22343
# 3          345020      Rincon de la Vieja            22346
# 4          353010              Fernandina            22347
#
#     eruption_category area_of_activity  vei  start_year  start_month  \
# 0  Confirmed Eruption              NaN  NaN      2020.0          3.0
# 1  Confirmed Eruption              NaN  NaN      2020.0          2.0
# 2  Confirmed Eruption              NaN  NaN      2020.0          2.0
# 3  Confirmed Eruption              NaN  NaN      2020.0          1.0
# 4  Confirmed Eruption              NaN  NaN      2020.0          1.0
#
#    start_day   evidence_method_dating  end_year  end_month  end_day  latitude  \
# 0       23.0  Historical Observations    2020.0        4.0      2.0     1.112
# ...

# %% [markdown]
# Least amount of number of volcanoes

# %%
volcanoes['volcano_name'].value_counts(ascending= True).head()
# Out:
# volcano_name
# Igwisi Hills                     1
# Nantaisan                        1
# Black Butte Crater Lava Field    1
# Berlin                           1
# Damavand                         1
# Name: count, dtype: int64

# %% [markdown]
# Most amount of numbers of volcanoes

# %%
volcanoes['volcano_name'].value_counts(ascending= False).head()
# Out:
# volcano_name
# Etna                      241
# Fournaise, Piton de la    194
# Asosan                    186
# Villarrica                164
# Asamayama                 147
# Name: count, dtype: int64

# %%
max_erruption_number = volcanoes['eruption_number'].max()
print('Max eruption number is '+ str(max_erruption_number))
# Out:
# Max eruption number is 22355
